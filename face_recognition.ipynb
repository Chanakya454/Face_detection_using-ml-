# %%
import cv2
import numpy as np

recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('trainer/trainer.yml')
cascadePath = "haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascadePath)

font = cv2.FONT_HERSHEY_TRIPLEX
id = 0
names = [0, 1, 2, 3, 4, 5]

cam = cv2.VideoCapture(0)
cam.set(3, 640)
cam.set(4, 480)

minW = 0.1 * cam.get(3)
minH = 0.1 * cam.get(4)

while True:
    ret, img = cam.read()

    # Check if the frame is successfully captured
    if not ret:
        print("Error: Failed to capture frame")
        break

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(int(minW), int(minH))
    )

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        id, confidence = recognizer.predict(gray[y:y+h, x:x+w])
        if confidence < 100:
            id = names[id]
            confidence = " {0}%".format(round(100 - confidence))
        else:
            id = "unknown"
            confidence = " {0}%".format(round(100 - confidence))
        cv2.putText(img, str(id), (x+5, y+5), font, 1, (255, 255, 255), 2)
        cv2.putText(img, str(confidence), (x+5, y+h-5), font, 1, (255, 255, 0), 1)

    cv2.imshow('camera', img)
    k = cv2.waitKey(10) & 0xff
    if k == 27:
        break

print("\n [INFO] Exiting the program")
cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 40
#      38 id, confidence = recognizer.predict(gray[y:y+h, x:x+w])
#      39 if confidence < 100:
# ---> 40     id = names[id]
#      41     confidence = " {0}%".format(round(100 - confidence))
#      42 else:
#
# IndexError: list index out of range

# %%
import cv2

recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('trainer/trainer.yml')
cascadePath = "haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascadePath)

font = cv2.FONT_HERSHEY_TRIPLEX
names = ["Person 0", "Person 1", "Person 2", "Person 3", "Person 4", "Person 5"]

cam = cv2.VideoCapture(0)
cam.set(3, 640)
cam.set(4, 480)

minW = 0.1 * cam.get(3)
minH = 0.1 * cam.get(4)

while True:
    ret, img = cam.read()

    if not ret:
        print("Error: Failed to capture frame")
        break

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.2,
        minNeighbors=5,
        minSize=(int(minW), int(minH))
    )

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        id, confidence = recognizer.predict(gray[y:y+h, x:x+w])

        if confidence < 100:
            if 0 <= id < len(names):
                person_name = names[id]
            else:
                person_name = "Unknown Person"
            confidence = " {0}%".format(round(100 - confidence))
        else:
            person_name = "Unknown Person"
            confidence = " {0}%".format(round(100 - confidence))

        cv2.putText(img, person_name, (x+5, y+5), font, 1, (255, 255, 255), 2)
        cv2.putText(img, str(confidence), (x+5, y+h-5), font, 1, (255, 255, 0), 1)

    cv2.imshow('camera', img)
    k = cv2.waitKey(10) & 0xff
    if k == 27:
        break

print("\n [INFO] Exiting the program")
cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 47
#      44         person_name = "Unknown Person"
#      45         confidence = " {0}%".format(round(100 - confidence))
# ---> 47     cv2.putText(img, person_name, (x+5, y+5), font, 1, (255, 255, 255), 2)
#      48     cv2.putText(img, str(confidence), (x+5, y+h-5), font, 1, (255, 255, 0), 1)
#      50 cv2.imshow('camera', img)
#
# KeyboardInterrupt:
